# %%
# !pip install SimpleITK
# !pip install wandb
# Out:
# Collecting SimpleITK
#   Downloading SimpleITK-2.4.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.9 kB)
# Downloading SimpleITK-2.4.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (52.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.4/52.4 MB 20.7 MB/s eta 0:00:00
# Installing collected packages: SimpleITK
# Successfully installed SimpleITK-2.4.0
# Requirement already satisfied: wandb in /usr/local/lib/python3.10/dist-packages (0.18.5)
# Requirement already satisfied: click!=8.0.0,>=7.1 in /usr/local/lib/python3.10/dist-packages (from wandb) (8.1.7)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (0.4.0)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (3.1.43)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.10/dist-packages (from wandb) (4.3.6)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<6,>=3.19.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (3.20.3)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from wandb) (6.0.2)
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (2.32.3)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (2.18.0)
# Requirement already satisfied: setproctitle in /usr/local/lib/python3.10/dist-packages (from wandb) (1.3.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from wandb) (75.1.0)
# Requirement already satisfied: typing-extensions<5,>=4.4 in /usr/local/lib/python3.10/dist-packages (from wandb) (4.12.2)
# Requirement already satisfied: six>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from docker-pycreds>=0.4.0->wandb) (1.16.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from gitpython!=3.1.29,>=1.0.0->wandb) (4.0.11)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.0.0->wandb) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.0.0->wandb) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.0.0->wandb) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.0.0->wandb) (2024.8.30)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb) (5.0.1)

# %%
import torch
import matplotlib.pyplot as plt
import numpy as np
from torch import nn
import cv2
import glob
import pandas as pd
import SimpleITK as sitk
import random
import wandb
import albumentations as A
from albumentations.pytorch import ToTensorV2
import shutil
import re
import os
# Out:
# /usr/local/lib/python3.10/dist-packages/albumentations/__init__.py:24: UserWarning: A new version of Albumentations is available: 1.4.21 (you have 1.4.20). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()

# %%
wandb.login()
# Out:
# wandb: Using wandb-core as the SDK backend. Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: aaryadev. Use `wandb login --relogin` to force relogin
# True

# %%
wandb.init(
    # set the wandb project where this run will be logged
    project="brats 3d tedunet",
)
# Out:
# Tracking run with wandb version 0.18.5
# Run data is saved locally in <code>/content/wandb/run-20241112_053007-5lwrgr2j</code>
# Syncing run <strong><a href='https://wandb.ai/aaryadev/brats%203d%20tedunet/runs/5lwrgr2j' target="_blank">dry-tree-41</a></strong> to <a href='https://wandb.ai/aaryadev/brats%203d%20tedunet' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/aaryadev/brats%203d%20tedunet' target="_blank">https://wandb.ai/aaryadev/brats%203d%20tedunet</a>
#  View run at <a href='https://wandb.ai/aaryadev/brats%203d%20tedunet/runs/5lwrgr2j' target="_blank">https://wandb.ai/aaryadev/brats%203d%20tedunet/runs/5lwrgr2j</a>
# <button onClick="this.nextSibling.style.display='block';this.style.display='none';">Display W&B run</button><iframe src='https://wandb.ai/aaryadev/brats%203d%20tedunet/runs/5lwrgr2j?jupyter=true' style='border:none;width:100%;height:420px;display:none;'></iframe>

# %%
# prompt: drive

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# input_tensor = torch.randn(1, 1, 91, 109, 91)

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# %%
def center_crop(tensor, target_dims):

        current_dims= tensor.shape
        start_indices = [(curr_dim - target_dim) // 2 for curr_dim, target_dim in zip(current_dims, target_dims)]
        end_indices = [start + target_dim for start, target_dim in zip(start_indices, target_dims)]

        cropped_data = tensor[
            start_indices[0]:end_indices[0],
            start_indices[1]:end_indices[1],
            start_indices[2]:end_indices[2],

        ]

        return cropped_data

# %%
class TEDUNet(nn.Module):
    def __init__(self, verbose):
        super(TEDUNet, self).__init__()

        self.verbose = verbose

        def conv_block(in_channels, out_channels):
            return nn.Sequential(
                nn.Conv3d(in_channels, out_channels, kernel_size=3, padding=1),
                nn.BatchNorm3d(out_channels),
                nn.LeakyReLU(),
                nn.Conv3d(out_channels, out_channels, kernel_size=3, padding=1),
                nn.BatchNorm3d(out_channels),
                nn.LeakyReLU()
            )

        def up_conv_block(in_channels, out_channels):
            return nn.ConvTranspose3d(in_channels, out_channels, kernel_size=2, stride=3, padding=1)

        # Downward path (encoding)
        self.conv_downwards = nn.ModuleList([
            conv_block(1, 64),
            nn.MaxPool3d(kernel_size=2, stride=1),
            conv_block(64, 128),
            nn.MaxPool3d(kernel_size=2, stride=2),
            conv_block(128, 256),
            nn.MaxPool3d(kernel_size=2, stride=1),
            conv_block(256, 512),
            nn.MaxPool3d(kernel_size=2, stride=2),
        ])

        # Bottleneck layer
        self.bottleneck_layer = nn.Sequential(
            nn.Conv3d(512, 1024, kernel_size=3, padding=1),
            nn.BatchNorm3d(1024),
            nn.LeakyReLU(),
            nn.Conv3d(1024, 1024, kernel_size=3, padding=1),
            nn.BatchNorm3d(1024),
            nn.LeakyReLU()
        )

        # Upward path (decoding)
        self.conv_upwards = nn.ModuleList([
            up_conv_block(1024, 512),
            conv_block(1024, 512),
            up_conv_block(512, 256),
            conv_block(512, 256),
            up_conv_block(256, 128),
            conv_block(256, 128),
            up_conv_block(128, 64),
            conv_block(128, 64),
        ])

        # Final 1x1 Conv layer
        self.conv_1x1 = nn.Conv3d(64, 1, kernel_size=1, padding=1)

        # Softmax
        self.sigmoid = nn.Sigmoid()



    def center_crop(self, tensor, target_dims):

        current_dims= tensor.shape
        start_indices = [(curr_dim - target_dim) // 2 for curr_dim, target_dim in zip(current_dims, target_dims)]
        end_indices = [start + target_dim for start, target_dim in zip(start_indices, target_dims)]

        cropped_data = tensor[
            :,
            :,
            start_indices[2]:end_indices[2],
            start_indices[3]:end_indices[3],
            start_indices[4]:end_indices[4],

        ]

        return cropped_data

    def forward(self, x):

        original_x_shape = x.shape
        # Downward path
        skip_connections = []
        for layer in self.conv_downwards:
            if isinstance(layer, nn.MaxPool3d):
                skip_connections.append(x)  # Save skip connection before MaxPool

            if self.verbose:
                print(f'applying {layer} => {x.shape}\n\n')
            x = layer(x)

        # Bottleneck
        x = self.bottleneck_layer(x)

        if self.verbose:
            print(f'applying bottleneck layer {self.bottleneck_layer} => {x.shape}\n\n')

        # Upward path
        for i in range(0, len(self.conv_upwards), 2):
            x = self.conv_upwards[i](x)
            if self.verbose:
                print(f'applying {self.conv_upwards[i]} => {x.shape}')

            popped_x = skip_connections.pop()

            if self.verbose:
                print(f'CONCATENATING')
                print('popped_x shape is ', popped_x.shape)
                print(f'x shape before concatenating is {x.shape}\n\n')
            x = self.center_crop(x, popped_x.shape)
            x = torch.cat((popped_x, x), dim=1)  # Concatenate with skip connection
            x = self.conv_upwards[i + 1](x)
            if self.verbose:
                print(f'applying layer {self.conv_upwards[i + 1]} => {x.shape}\n\n')

        # Final 1x1 Conv
        x = self.conv_1x1(x)

        if self.verbose:
            print(f'applying conv 1x1 => {x.shape}\n\n')
        x = self.sigmoid(x)

        x = self.center_crop(x, original_x_shape)


        return x

# %% [markdown]
# ## Convert Sample to Sliced Spaces

# %%
subject_folder_names = glob.glob('/content/drive/MyDrive/learning machine learning/T2F + Segmap Samples/*')
sliced_spaces_save_folder_name = "Space Slice Dataset"

# shutil.rmtree('./' + sliced_spaces_save_folder_name)

if sliced_spaces_save_folder_name not in os.listdir():
  os.mkdir(sliced_spaces_save_folder_name)

# %%
import albumentations as A
from albumentations.pytorch import ToTensorV2

# Define transformations
transform = A.Compose([
    A.HorizontalFlip(p=0.5),
    A.VerticalFlip(p=0.5),
    A.RandomRotate90(p=0.5),
    A.RandomBrightnessContrast(p=0.2),
    A.ElasticTransform(p=0.1),
])


def augment(image, mask, transform=transform):
    augmented = transform(image=image, mask=mask)
    augmented_image = augmented["image"]
    augmented_mask = augmented["mask"]
    return augmented_image, augmented_mask

# %%
samples_to_write = 15000
init_stw = samples_to_write
break_outer_loop = False

subjects_read = 0

for subject in subject_folder_names:

  print(f'\n\nReading subject {subjects_read}')
  subjects_read += 1

  file_paths = sorted(glob.glob(subject + '/*'))

  segmap_path = file_paths[0]
  image_path = file_paths[1]

  sample_name = subject.split('/')[-1]

  image = sitk.ReadImage(image_path)
  image_array = sitk.GetArrayFromImage(image)

  segmap = sitk.ReadImage(segmap_path)
  segmap_array = sitk.GetArrayFromImage(segmap)



  # functoin to convert all class labels that are > 1, to 1
  # to convert this into a single class segmentation problem

  def np_convert_nonzero_to_one(mask_tensor):
    for i in range(mask_tensor.shape[0]):
      for j in range(mask_tensor.shape[1]):
        for k in range(mask_tensor.shape[2]):
          if int(mask_tensor[i, j, k]) > 1:
            mask_tensor[i, j, k] = 1.0

    return mask_tensor


  segmap_array = np_convert_nonzero_to_one(segmap_array)


  # performing jump based space divisions

  jump_coords = [26, 26, 26]


  # # lists to store each space slice to be saved
  # image_space_slices = []
  # segmap_space_slices = []


  # logic to slice a space out of a 3d array
  # each slice space is then saved as an nii.gz file to be read by the dataloader while training
  # space slices are created for both, the image and the segmentation mask

  it0 = 1

  while it0 * jump_coords[1] < image_array.shape[1]:

      it1 = 1
      while it1 * jump_coords[2] < image_array.shape[2]:
          it2 = 1
          while it2 * jump_coords[0] < image_array.shape[0]:

              # slicing space from image
              curr_image_slice = image_array[(it2 - 1) * jump_coords[0]:it2*jump_coords[0], (it0-1) * jump_coords[1]:it0*jump_coords[1], (it1-1)*jump_coords[2]:it1*jump_coords[2]]

              # slicing space from segmantation map
              curr_segmap_slice = segmap_array[(it2 - 1) * jump_coords[0]:it2*jump_coords[0], (it0-1) * jump_coords[1]:it0*jump_coords[1], (it1-1)*jump_coords[2]:it1*jump_coords[2]]

              # if 1.0 in list(set(curr_segmap_slice.reshape(-1))) or random.randint(0, 4) == 0:
              if sum(list(curr_segmap_slice.reshape(-1))) > 10.0:

                curr_image_slice, curr_segmap_slice = augment(curr_image_slice, curr_segmap_slice)
                # write new samples space slices
                sitk.WriteImage(sitk.GetImageFromArray(curr_image_slice), f'./Space Slice Dataset/{sample_name}{it0}_{it1}_{it2}_data.nii.gz')
                sitk.WriteImage(sitk.GetImageFromArray(curr_segmap_slice), f'./Space Slice Dataset/{sample_name}{it0}_{it1}_{it2}_seg.nii.gz')

                samples_to_write -= 1
                print(f'{init_stw - samples_to_write} sample/s written')


                if not samples_to_write:
                  break_outer_loop = True
                  break

              it2 += 1
          it1 += 1
          if break_outer_loop:
            break
      it0 += 1
      if break_outer_loop:
            break

  if break_outer_loop:
    break
# Out:
# Streaming output truncated to the last 5000 lines.
# 5594 sample/s written
# 5595 sample/s written
# 5596 sample/s written
# 5597 sample/s written
# 5598 sample/s written
# 5599 sample/s written
# 5600 sample/s written
# 5601 sample/s written
# 5602 sample/s written
# 5603 sample/s written
# 5604 sample/s written
# 5605 sample/s written
# 5606 sample/s written
# 5607 sample/s written
# 5608 sample/s written
# 5609 sample/s written
# 5610 sample/s written
# 5611 sample/s written
# 5612 sample/s written
# 5613 sample/s written
# 5614 sample/s written
# 5615 sample/s written
# 5616 sample/s written
# 5617 sample/s written
# 5618 sample/s written
# 5619 sample/s written
#
#
# Reading subject 229
# 5620 sample/s written
# 5621 sample/s written
# 7068 sample/s written
# 7069 sample/s written
#
#
# Reading subject 286
# 7070 sample/s written
# 7071 sample/s written
# 7072 sample/s written
# 7073 sample/s written
# 7074 sample/s written
# 7075 sample/s written
# 7076 sample/s written
# 7077 sample/s written
# 7078 sample/s written
# 7079 sample/s written
# 7080 sample/s written
# 7081 sample/s written
# 7082 sample/s written
# 7083 sample/s written
# 7084 sample/s written
# 7085 sample/s written
# 7086 sample/s written
# 7087 sample/s written
# 7088 sample/s written
# 7089 sample/s written
# 7090 sample/s written
# 7091 sample/s written
# 7092 sample/s written
# 7093 sample/s written
#
#
# Reading subject 287
# 7094 sample/s written
# 7095 sample/s written
# 7096 sample/s written
# 7097 sample/s written
# 7098 sample/s written
# 7099 sample/s written
# 7100 sample/s written
# 7101 sample/s written
# 7102 sample/s written
# 7103 sample/s written
# 7104 sample/s written
# 7105 sample/s written
# 7106 sample/s written
# 7107 sample/s written
# 7108 sample/s written
# 7109 sample/s written
# 7110 sample/s written
# 7111 sample/s written
# 7112 sample/s written
# 7113 sample/s written
# 7114 sample/s written
# 7115 sample/s written
# 7116 sample/s written
# 7117 sample/s written
# 7118 sample/s written
# 7119 sample/s written
# 7120 sample/s written
# 7121 sample/s written
# 7122 sample/s written
# 7123 sample/s written
# 7124 sample/s written
#
#
# Reading subject 288
# 7125 sample/s written
# 7126 sample/s written
# 7127 sample/s written
# 7128 sample/s written
# 7129 sample/s written
# 7130 sample/s written
# 7131 sample/s written
# 7132 sample/s written
# 7133 sample/s written
# 7134 sample/s written
# 7135 sample/s written
# 7136 sample/s written
# 7137 sample/s written
# 7138 sample/s written
# 7139 sample/s written
# 7140 sample/s written
# 7141 sample/s written
# 7142 sample/s written
# 7143 sample/s written
# 7144 sample/s written
# 7145 sample/s written
# 7146 sample/s written
#
#
# Reading subject 289
# 7147 sample/s written
# 7148 sample/s written
# 7149 sample/s written
# 7150 sample/s written
# 7151 sample/s written
# 7152 sample/s written
# 7153 sample/s written
# 7154 sample/s written
# 7155 sample/s written
# 7156 sample/s written
# 7157 sample/s written
# 7158 sample/s written
# 7159 sample/s written
# 7160 sample/s written
# 7161 sample/s written
# 7162 sample/s written
# 7163 sample/s written
# 7164 sample/s written
# 7165 sample/s written
# 7166 sample/s written
# 7167 sample/s written
# 7168 sample/s written
# 7169 sample/s written
#
#
# Reading subject 290
# 7170 sample/s written
# 7171 sample/s written
# 7172 sample/s written
# 7173 sample/s written
# 7174 sample/s written
# 7175 sample/s written
# 7176 sample/s written
# 7177 sample/s written
# 7178 sample/s written
# 7179 sample/s written
# 7180 sample/s written
# 7181 sample/s written
# 7182 sample/s written
# 7183 sample/s written
# 7184 sample/s written
# 7185 sample/s written
# 7186 sample/s written
# 7187 sample/s written
# 7188 sample/s written
# 7189 sample/s written
# 7190 sample/s written
# 7191 sample/s written
# 7192 sample/s written
# 7193 sample/s written
# 7194 sample/s written
# 7195 sample/s written
# 7196 sample/s written
# 7197 sample/s written
# 7198 sample/s written
# 7199 sample/s written
# 7200 sample/s written
# 7201 sample/s written
# 7202 sample/s written
# 7203 sample/s written
# 7204 sample/s written
# 7205 sample/s written
# 7206 sample/s written
# 7207 sample/s written
# 7208 sample/s written
# 7209 sample/s written
# 7210 sample/s written
# 7211 sample/s written
# 7212 sample/s written
# 7213 sample/s written
# 7214 sample/s written
# 7215 sample/s written
# 7216 sample/s written
# 7217 sample/s written
# 7218 sample/s written
# 7219 sample/s written
# 7220 sample/s written
# 7221 sample/s written
# 7222 sample/s written
#
#
# Reading subject 291
# 7223 sample/s written
# 7224 sample/s written
# 7225 sample/s written
# 7226 sample/s written
# 7227 sample/s written
# 7228 sample/s written
# 7229 sample/s written
# 7230 sample/s written
# 7231 sample/s written
# 7232 sample/s written
# 7233 sample/s written
# 7234 sample/s written
# 7235 sample/s written
# 7236 sample/s written
# 7237 sample/s written
# 7238 sample/s written
# 7239 sample/s written
# 7240 sample/s written
# 7241 sample/s written
# 7242 sample/s written
# 7243 sample/s written
# 7244 sample/s written
# 7245 sample/s written
# 7246 sample/s written
# 7247 sample/s written
# 7248 sample/s written
# 7249 sample/s written
#
#
# Reading subject 292
# 7250 sample/s written
# 7251 sample/s written
# 7252 sample/s written
# 7253 sample/s written
# 7254 sample/s written
# 7255 sample/s written
# 7256 sample/s written
# 7257 sample/s written
# 7258 sample/s written
# 7259 sample/s written
# 7260 sample/s written
#
#
# Reading subject 293
# 7261 sample/s written
# 7262 sample/s written
# 7263 sample/s written
# 7264 sample/s written
# 7265 sample/s written
# 7266 sample/s written
# 7267 sample/s written
# 7268 sample/s written
# 7269 sample/s written
# 7270 sample/s written
# 7271 sample/s written
# 7272 sample/s written
# 7273 sample/s written
# 7274 sample/s written
# 7275 sample/s written
# 7276 sample/s written
# 7277 sample/s written
# 7278 sample/s written
# 7279 sample/s written
# 7280 sample/s written
# 7281 sample/s written
# 7282 sample/s written
# 7283 sample/s written
# 7284 sample/s written
# 7285 sample/s written
# 7286 sample/s written
# 7287 sample/s written
# 7288 sample/s written
# 7289 sample/s written
# 7290 sample/s written
# 7291 sample/s written
# 7292 sample/s written
# 7293 sample/s written
# 7294 sample/s written
# 7295 sample/s written
# 7296 sample/s written
# 7297 sample/s written
# 7298 sample/s written
# 7299 sample/s written
# 7300 sample/s written
# 7301 sample/s written
# 7302 sample/s written
# 7303 sample/s written
# 7304 sample/s written
# 7305 sample/s written
# 7306 sample/s written
# 7307 sample/s written
#
#
# Reading subject 294
# 7308 sample/s written
# 7309 sample/s written
# 7310 sample/s written
# 7311 sample/s written
# 7312 sample/s written
# 7313 sample/s written
# 7314 sample/s written
# 7315 sample/s written
# 7316 sample/s written
# 7317 sample/s written
# 7318 sample/s written
# 7319 sample/s written
# 7320 sample/s written
# 7321 sample/s written
# 7322 sample/s written
# 7323 sample/s written
# 7324 sample/s written
# 7325 sample/s written
# 7326 sample/s written
# 7327 sample/s written
# 7328 sample/s written
# 7329 sample/s written
# 7330 sample/s written
# 7331 sample/s written
# 7332 sample/s written
#
#
# Reading subject 295
# 7333 sample/s written
# 7334 sample/s written
# 7335 sample/s written
# 7336 sample/s written
# 7337 sample/s written
# 7338 sample/s written
# 7339 sample/s written
# 7340 sample/s written
# 7341 sample/s written
# 7342 sample/s written
# 7343 sample/s written
# 7344 sample/s written
# 7345 sample/s written
# 7346 sample/s written
# 7347 sample/s written
# 7348 sample/s written
# 7349 sample/s written
# 7350 sample/s written
# 7351 sample/s written
# 7352 sample/s written
# 7353 sample/s written
#
#
# Reading subject 296
# 7354 sample/s written
# 7355 sample/s written
# 7356 sample/s written
# 7357 sample/s written
# 7358 sample/s written
# 7359 sample/s written
# 7360 sample/s written
# 7361 sample/s written
# 7362 sample/s written
# 7363 sample/s written
# 7364 sample/s written
# 7365 sample/s written
# 7366 sample/s written
# 7367 sample/s written
# 7368 sample/s written
# 7369 sample/s written
# 7370 sample/s written
# 7371 sample/s written
# 7372 sample/s written
# 7373 sample/s written
# 7374 sample/s written
# 7375 sample/s written
# 7376 sample/s written
# 7377 sample/s written
# 7378 sample/s written
# 7379 sample/s written
# 7380 sample/s written
# 7381 sample/s written
# 7382 sample/s written
# 7383 sample/s written
#
#
# Reading subject 297
# 7384 sample/s written
# 7385 sample/s written
# 7386 sample/s written
# 7387 sample/s written
# 7388 sample/s written
# 7389 sample/s written
# 7390 sample/s written
# 7391 sample/s written
# 7392 sample/s written
# 7393 sample/s written
# 7394 sample/s written
# 7395 sample/s written
# 7396 sample/s written
# 7397 sample/s written
# 7398 sample/s written
# 7399 sample/s written
# 7400 sample/s written
# 7401 sample/s written
# 7402 sample/s written
#
#
# Reading subject 298
# 7403 sample/s written
# 7404 sample/s written
# 7405 sample/s written
# 7406 sample/s written
# 7407 sample/s written
# 7408 sample/s written
# 7409 sample/s written
# 7410 sample/s written
# 7411 sample/s written
# 7412 sample/s written
# 7413 sample/s written
# 7414 sample/s written
# 7415 sample/s written
# 7416 sample/s written
# 7417 sample/s written
# 7418 sample/s written
# 7419 sample/s written
# 7420 sample/s written
# 7421 sample/s written
# 7422 sample/s written
# 7423 sample/s written
# 7424 sample/s written
# 7425 sample/s written
# 7426 sample/s written
# 7427 sample/s written
#
#
# Reading subject 299
# 7428 sample/s written
# 7429 sample/s written
# 7430 sample/s written
# 7431 sample/s written
# 7432 sample/s written
# 7433 sample/s written
# 7434 sample/s written
# 7435 sample/s written
# 7436 sample/s written
# 7437 sample/s written
# 7438 sample/s written
# 7439 sample/s written
# 7440 sample/s written
# 7441 sample/s written
# 7442 sample/s written
# 7443 sample/s written
# 7444 sample/s written
# 7445 sample/s written
# 7446 sample/s written
# 7447 sample/s written
# 7448 sample/s written
# 7449 sample/s written
# 7450 sample/s written
# 7451 sample/s written
# 7452 sample/s written
# 7453 sample/s written
# 7454 sample/s written
# 7455 sample/s written
# 7456 sample/s written
# 7457 sample/s written
# 7458 sample/s written
# 7459 sample/s written
# 7460 sample/s written
# 7461 sample/s written
# 7462 sample/s written
# 7463 sample/s written
# 7464 sample/s written
# 7465 sample/s written
# 7466 sample/s written
# 7467 sample/s written
# 7468 sample/s written
# 7469 sample/s written
# 7470 sample/s written
# 7471 sample/s written
# 7472 sample/s written
# 7473 sample/s written
# 7474 sample/s written
#
#
# Reading subject 300
# 7475 sample/s written
# 7476 sample/s written
# 7477 sample/s written
# 7478 sample/s written
# 7479 sample/s written
# 7480 sample/s written
# 7481 sample/s written
# 7482 sample/s written
# 7483 sample/s written
# 7484 sample/s written
# 7485 sample/s written
# 7486 sample/s written
# 7487 sample/s written
# 7488 sample/s written
# 7489 sample/s written
# 7490 sample/s written
# 7491 sample/s written
# 7492 sample/s written
# 7493 sample/s written
# 7494 sample/s written
# 7495 sample/s written
# 7496 sample/s written
# 7497 sample/s written
# 7498 sample/s written
# 7499 sample/s written
# 7500 sample/s written
# 7501 sample/s written
# 7502 sample/s written
# 7503 sample/s written
# 7504 sample/s written
# 7505 sample/s written
# 7506 sample/s written
# 7507 sample/s written
# 7508 sample/s written
# 7509 sample/s written
# 7510 sample/s written
# 7511 sample/s written
#
#
# Reading subject 301
# 7512 sample/s written
# 7513 sample/s written
# 7514 sample/s written
# 7515 sample/s written
# 7516 sample/s written
# 7517 sample/s written
# 7518 sample/s written
# 7519 sample/s written
# 7520 sample/s written
# 7521 sample/s written
# 7522 sample/s written
# 7523 sample/s written
# 7524 sample/s written
# 7525 sample/s written
# 7526 sample/s written
# 7527 sample/s written
# 7528 sample/s written
# 7529 sample/s written
# 7530 sample/s written
# 7531 sample/s written
# 7532 sample/s written
# 7533 sample/s written
# 7534 sample/s written
# 7535 sample/s written
# 7536 sample/s written
# 7537 sample/s written
# 7538 sample/s written
# 7539 sample/s written
# 7540 sample/s written
# 7541 sample/s written
# 7542 sample/s written
# 7543 sample/s written
# 7544 sample/s written
# 7545 sample/s written
# 7546 sample/s written
# 7547 sample/s written
# 7548 sample/s written
# 7549 sample/s written
# 7550 sample/s written
# 7551 sample/s written
#
#
# Reading subject 302
# 7552 sample/s written
# 7553 sample/s written
# 7554 sample/s written
# 7555 sample/s written
# 7556 sample/s written
# 7557 sample/s written
# 7558 sample/s written
# 7559 sample/s written
# 7560 sample/s written
# 7561 sample/s written
# 7562 sample/s written
# 7563 sample/s written
# 7564 sample/s written
# 7565 sample/s written
# 7566 sample/s written
# 7567 sample/s written
# 7568 sample/s written
# 7569 sample/s written
# 7570 sample/s written
# 7571 sample/s written
# 7572 sample/s written
# 7573 sample/s written
# 7574 sample/s written
# 7575 sample/s written
# 7576 sample/s written
# 7577 sample/s written
# 7578 sample/s written
# 7579 sample/s written
# 7580 sample/s written
# 7581 sample/s written
# 7582 sample/s written
# 7583 sample/s written
# 7584 sample/s written
# 7585 sample/s written
# 7586 sample/s written
# 7587 sample/s written
# 7588 sample/s written
# 7589 sample/s written
# 7590 sample/s written
# 7591 sample/s written
#
#
# Reading subject 303
# 7592 sample/s written
# 7593 sample/s written
# 7594 sample/s written
# 7595 sample/s written
# 7596 sample/s written
# 7597 sample/s written
# 7598 sample/s written
# 7599 sample/s written
# 7600 sample/s written
# 7601 sample/s written
# 7602 sample/s written
# 7603 sample/s written
# 7604 sample/s written
# 7605 sample/s written
# 7606 sample/s written
# 7607 sample/s written
# 7608 sample/s written
# 7609 sample/s written
# 7610 sample/s written
# 7611 sample/s written
# 7612 sample/s written
# 7613 sample/s written
# 7614 sample/s written
# 7615 sample/s written
# 7616 sample/s written
# 7617 sample/s written
# 7618 sample/s written
# 7619 sample/s written
# 7620 sample/s written
#
#
# Reading subject 304
# 7621 sample/s written
# 7622 sample/s written
# 7623 sample/s written
# 7624 sample/s written
# 7625 sample/s written
# 7626 sample/s written
# 7627 sample/s written
# 7628 sample/s written
# 7629 sample/s written
# 7630 sample/s written
# 7631 sample/s written
# 7632 sample/s written
# 7633 sample/s written
# 7634 sample/s written
# 7635 sample/s written
# 7636 sample/s written
# 7637 sample/s written
# 7638 sample/s written
# 7639 sample/s written
# 7640 sample/s written
# 7641 sample/s written
# 7642 sample/s written
# 7643 sample/s written
# 7644 sample/s written
# 7645 sample/s written
# 7646 sample/s written
# 7647 sample/s written
# 7648 sample/s written
# 7649 sample/s written
# 7650 sample/s written
# 7651 sample/s written
# 7652 sample/s written
# 7653 sample/s written
# 7654 sample/s written
# 7655 sample/s written
# 7656 sample/s written
# 7657 sample/s written
# 7658 sample/s written
# 7659 sample/s written
# 7660 sample/s written
# 7661 sample/s written
# 7662 sample/s written
# 7663 sample/s written
# 7664 sample/s written
# 7665 sample/s written
# 7666 sample/s written
# 7667 sample/s written
# 7668 sample/s written
# 7669 sample/s written
# 7670 sample/s written
#
#
# Reading subject 305
# 7671 sample/s written
# 7672 sample/s written
# 7673 sample/s written
# 7674 sample/s written
# 7675 sample/s written
# 7676 sample/s written
# 7677 sample/s written
# 7678 sample/s written
# 7679 sample/s written
# 7680 sample/s written
# 7681 sample/s written
# 7682 sample/s written
# 7683 sample/s written
# 7684 sample/s written
# 7685 sample/s written
# 7686 sample/s written
# 7687 sample/s written
# 7688 sample/s written
# 7689 sample/s written
# 7690 sample/s written
# 7691 sample/s written
# 7692 sample/s written
# 7693 sample/s written
# 7694 sample/s written
# 7695 sample/s written
# ...
# 9504 sample/s written
# 9505 sample/s written
# 9506 sample/s written
# 9507 sample/s written
# 9508 sample/s written
# 9509 sample/s written
# 9510 sample/s written
# 9511 sample/s written
# 9512 sample/s written
# 9513 sample/s written
# 9514 sample/s written
# 9515 sample/s written
# 9516 sample/s written
# 9517 sample/s written
# 9518 sample/s written
# 9519 sample/s written
# 9520 sample/s written
# 9521 sample/s written
# 9522 sample/s written
# 9523 sample/s written
# 9524 sample/s written
# 9525 sample/s written
#
#
# Reading subject 373
# 9526 sample/s written
# 9527 sample/s written
# 9528 sample/s written
# 9529 sample/s written
# 9530 sample/s written
# 9531 sample/s written
# 9532 sample/s written
# 9533 sample/s written
# 9534 sample/s written
# 9535 sample/s written
# 9536 sample/s written
# 9537 sample/s written
# 9928 sample/s written
# 9929 sample/s written
# 9930 sample/s written
# 9931 sample/s written
# 9932 sample/s written
# 9933 sample/s written
# 9934 sample/s written
# 9935 sample/s written
# 9936 sample/s written
# 9937 sample/s written
# 9938 sample/s written
# 9939 sample/s written
#
#
# Reading subject 393
# 9940 sample/s written
# 9941 sample/s written
# 9942 sample/s written
# 9943 sample/s written
# 9944 sample/s written
# 9945 sample/s written
# 9946 sample/s written
# 9947 sample/s written
# 9948 sample/s written
# 9949 sample/s written
# 9950 sample/s written
# 9951 sample/s written
#
#
# Reading subject 394
# 9952 sample/s written
# 9953 sample/s written
# 9954 sample/s written
# 9955 sample/s written
# 9956 sample/s written
# 9957 sample/s written
# 9958 sample/s written
# 9959 sample/s written
# 9960 sample/s written
# 9961 sample/s written
# 9962 sample/s written
# 9963 sample/s written
# 9964 sample/s written
#
#
# Reading subject 395
# 9965 sample/s written
# 9966 sample/s written
# 9967 sample/s written
# 9968 sample/s written
# 9969 sample/s written
# 9970 sample/s written
# 9971 sample/s written
# 9972 sample/s written
# 9973 sample/s written
# 9974 sample/s written
# 9975 sample/s written
# 9976 sample/s written
# 9977 sample/s written
# 9978 sample/s written
# 9979 sample/s written
# 9980 sample/s written
# 9981 sample/s written
# 9982 sample/s written
# 9983 sample/s written
# 9984 sample/s written
#
#
# Reading subject 396
# 9985 sample/s written
# 9986 sample/s written
# 9987 sample/s written
# 9988 sample/s written
# 9989 sample/s written
# 9990 sample/s written
# 9991 sample/s written
# 9992 sample/s written
# 9993 sample/s written
# 9994 sample/s written
# 9995 sample/s written
# 9996 sample/s written
# 9997 sample/s written
# 9998 sample/s written
# 9999 sample/s written
# 10000 sample/s written
# 10001 sample/s written
# 10002 sample/s written
# 10003 sample/s written
# 10004 sample/s written
# 10005 sample/s written
# 10006 sample/s written
# 10007 sample/s written
# 10008 sample/s written
# 10009 sample/s written
#
#
# Reading subject 397
# 10010 sample/s written
# 10011 sample/s written
# 10012 sample/s written
# 10013 sample/s written
# 10014 sample/s written
# 10015 sample/s written
# 10016 sample/s written
# 10017 sample/s written
# 10018 sample/s written
# 10019 sample/s written
# 10020 sample/s written
# 10021 sample/s written
# 10022 sample/s written
# 10023 sample/s written
# 10024 sample/s written
# 10025 sample/s written
# 10026 sample/s written
# 10027 sample/s written
# 10028 sample/s written
# 10029 sample/s written
# 10030 sample/s written
# 10031 sample/s written
# 10032 sample/s written
# 10033 sample/s written
# 10034 sample/s written
# 10035 sample/s written
#
#
# Reading subject 398
# 10036 sample/s written
# 10037 sample/s written
# 10038 sample/s written
# 10039 sample/s written
# 10040 sample/s written
# 10041 sample/s written
# 10042 sample/s written
# 10043 sample/s written
# 10044 sample/s written
# 10045 sample/s written
# 10046 sample/s written
# 10047 sample/s written
# 10048 sample/s written
# 10049 sample/s written
# 10050 sample/s written
# 10051 sample/s written
# 10052 sample/s written
#
#
# Reading subject 399
# 10053 sample/s written
# 10054 sample/s written
# 10055 sample/s written
# 10056 sample/s written
# 10057 sample/s written
# 10058 sample/s written
# 10059 sample/s written
# 10060 sample/s written
# 10061 sample/s written
# 10062 sample/s written
# 10063 sample/s written
# 10064 sample/s written
#
#
# Reading subject 400
# 10065 sample/s written
# 10066 sample/s written
# 10067 sample/s written
# 10068 sample/s written
# 10069 sample/s written
# 10070 sample/s written
# 10071 sample/s written
# 10072 sample/s written
# 10073 sample/s written
# 10074 sample/s written
# 10075 sample/s written
# 10076 sample/s written
# 10077 sample/s written
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-64eb81aa7a62> in <cell line: 7>()
#      73               if sum(list(curr_segmap_slice.reshape(-1))) > 10.0:
#      74
# ---> 75                 curr_image_slice, curr_segmap_slice = augment(curr_image_slice, curr_segmap_slice)
#      76                 # write new samples space slices
#      77                 sitk.WriteImage(sitk.GetImageFromArray(curr_image_slice), f'./Space Slice Dataset/{sample_name}{it0}_{it1}_{it2}_data.nii.gz')
#
# <ipython-input-12-843b0cad178e> in augment(image, mask, transform)
#      13
#      14 def augment(image, mask, transform=transform):
# ---> 15     augmented = transform(image=image, mask=mask)
#      16     augmented_image = augmented["image"]
#      17     augmented_mask = augmented["mask"]
#
# /usr/local/lib/python3.10/dist-packages/albumentations/core/composition.py in __call__(self, force_apply, *args, **data)
#     384
#     385         for t in self.transforms:
# --> 386             data = t(**data)
#     387             data = self.check_data_post_transform(data)
#     388
#
# /usr/local/lib/python3.10/dist-packages/albumentations/core/transforms_interface.py in __call__(self, force_apply, *args, **kwargs)
#     124             if self.deterministic:
#     125                 kwargs[self.save_key][id(self)] = deepcopy(params)
# --> 126             return self.apply_with_params(params, **kwargs)
#     127
#     128         return kwargs
#
# /usr/local/lib/python3.10/dist-packages/albumentations/core/transforms_interface.py in apply_with_params(self, params, *args, **kwargs)
#     143                 target_function = self._key2func[key]
#     144                 res[key] = ensure_contiguous_output(
# --> 145                     target_function(ensure_contiguous_output(arg), **params),
#     146                 )
#     147             else:
#
# /usr/local/lib/python3.10/dist-packages/albumentations/augmentations/transforms.py in apply(self, img, alpha, beta, **params)
#    2380
#    2381     def apply(self, img: np.ndarray, alpha: float, beta: float, **params: Any) -> np.ndarray:
# -> 2382         return fmain.brightness_contrast_adjust(img, alpha, beta, self.brightness_by_max)
#    2383
#    2384     def get_params(self) -> dict[str, float]:
#
# /usr/local/lib/python3.10/dist-packages/albumentations/augmentations/functional.py in brightness_contrast_adjust(img, alpha, beta, beta_by_max)
#     989 ) -> np.ndarray:
#     990     if beta_by_max:
# --> 991         max_value = MAX_VALUES_BY_DTYPE[img.dtype]
#     992         value = beta * max_value
#     993     else:
#
# KeyError: dtype('int16')

# %% [markdown]
# ## Create Dataset

# %%
# create Dataset for new sliced spaces

class SlicedSpacesDataset(torch.utils.data.Dataset):
  def __init__(self, dirname=sliced_spaces_save_folder_name):
    self.data_filenames = sorted(glob.glob(f'./{dirname}/*_data.nii.gz'))
    self.seg_filenames = sorted(glob.glob(f'./{dirname}/*_seg.nii.gz'))

    # fn to extract the four numbers from the filename
    def extract_numbers(filename):
        match = re.search(r'(\d+)-(\d+)_(\d+)_(\d+)', filename)
        if match:
            return tuple(map(int, match.groups()))  # return as tuple of integers
        return None

    # Dictionary to hold pairs
    self.file_pairs = []

    # Find matching pairs
    for data_file in self.data_filenames:
        data_nums = extract_numbers(data_file)
        if data_nums:
            for seg_file in self.seg_filenames:
                seg_nums = extract_numbers(seg_file)
                if seg_nums == data_nums:
                    self.file_pairs.append((data_file, seg_file))
                    break

  def __len__(self):
      return len(self.seg_filenames)

  def __getitem__(self, idx):
    image = sitk.ReadImage(self.file_pairs[idx][0])
    image_array = sitk.GetArrayFromImage(image)
    image_array = ((image_array - np.mean(image_array)) / (np.std(image_array) + 1e-7)) # adding term for when stddev =0

    image_tensor = torch.from_numpy(image_array).unsqueeze(0)

    segmap = sitk.ReadImage(self.file_pairs[idx][1])
    segmap_array = sitk.GetArrayFromImage(segmap)

    # convert to edge detected segmaps

    edged_imgs = []
    for i in range(segmap_array.shape[0]):
      img = cv2.Canny(segmap_array[i].astype(np.uint8), 0, 1)
      edged_imgs.append(img)

    edged_segmap = np.array(edged_imgs)

    segmap_tensor = torch.from_numpy(edged_segmap).unsqueeze(0)

    segmap_tensor = segmap_tensor.type(torch.float32)

    if segmap_tensor.max() > 1:
      segmap_tensor = segmap_tensor / 255

    return image_tensor, segmap_tensor

# %%
dataset = SlicedSpacesDataset()

# %%
train_dataset, test_dataset = torch.utils.data.random_split(dataset, [int(0.8*len(dataset)), len(dataset) - int(0.8*len(dataset))])
train_dataloader = torch.utils.data.DataLoader(train_dataset, batch_size=8, shuffle=True)
test_dataloader = torch.utils.data.DataLoader(test_dataset, batch_size=8, shuffle=True)

# %%
class DiceLoss(nn.Module):

    def __init__(self, smooth=1e-6):
        super(DiceLoss, self).__init__()
        self.smooth = smooth

    def dice_coeff(self, pred, target, smooth=1e-6):
        """
        Compute the Dice coefficient for binary classification.

        Parameters:
        - pred: Predicted tensor (probabilities).
        - target: Ground truth tensor (binary).
        - smooth: Smoothing factor to avoid division by zero.

        Returns:
        - Dice coefficient (mean over batch).
        """
        # Flatten tensors
        pred = pred.view(-1)
        target = target.view(-1)

        # Compute intersection and union
        intersection = (pred * target).sum()
        union = pred.sum() + target.sum()

        # Compute Dice coefficient
        dice = (2. * intersection + smooth) / (union + smooth)
        return dice

    def dice_loss(self, pred, target):
        """
        Compute the Dice loss for binary classification.

        Parameters:
        - pred: Predicted tensor (logits or probabilities).
        - target: Ground truth tensor (binary).
        - smooth: Smoothing factor to avoid division by zero.

        Returns:
        - Dice loss (1 - Dice coefficient).
        """
        # Apply sigmoid to get probabilities if not already applied
        pred = torch.sigmoid(pred)

        # Compute Dice coefficient
        dice = self.dice_coeff(pred, target, smooth=self.smooth)

        # Dice loss is 1 - Dice coefficient
        return 1 - dice

    def forward(self, pred, target):
        return self.dice_loss(pred, target)

# %%
tedu = TEDUNet(verbose=False).to(device)
bce_loss = nn.BCELoss()
dice_loss = DiceLoss()
optimizer = torch.optim.Adam(tedu.parameters(), lr=3e-4, weight_decay=1e-5)

# %%
epochs = 200
for _ in range(epochs):
  print(f'\n\n\nEpoch {_ + 1}')
  for batch_idx, (data, segmap) in enumerate(train_dataloader):

    data = data.to(device)
    segmap = segmap.to(device)

    output = tedu(data.float())

    loss = bce_loss(output, segmap.float()) + dice_loss(output, segmap.float())
    print(f'Batch:{batch_idx} ; Loss:{loss.item()}')

    loss.backward()
    optimizer.step()
    optimizer.zero_grad()



    with torch.no_grad():
      try:
        # plotting intermediate test results

        sample_number = random.randint(0, 3)
        slice_number = random.randint(0, 25)

        test_data, test_segmap = next(iter(test_dataloader))
        test_data, test_segmap = test_data.to(device), test_segmap.to(device)

        test_output = tedu(test_data.float())

        test_loss = bce_loss(test_output, test_segmap.float()) + 2 * dice_loss(test_output, test_segmap.float())
        wandb.log({
            'train loss': loss.item(),
            'test loss': test_loss.item()
        })

        fig, axs = plt.subplots(2, 2, figsize=(12, 6))

        axs[0, 0].imshow(test_segmap[sample_number][0][slice_number].detach().cpu().numpy(), cmap='gray')
        axs[0, 0].set_title('Test GT Segmap Slice')

        axs[0, 1].imshow(test_output[sample_number][0][slice_number].detach().cpu().numpy(), cmap='gray')
        axs[0, 1].set_title('Test Pred Segmap Slice')


        axs[1, 0].imshow(segmap[sample_number][0][slice_number].detach().cpu().numpy(), cmap='gray')
        axs[1, 0].set_title('Train GT Segmap Slice')

        axs[1, 1].imshow(output[sample_number][0][slice_number].detach().cpu().numpy(), cmap='gray')
        axs[1, 1].set_title('Train Pred Segmap Slice')

        # Log the figure to W&B
        wandb.log({
            "Predictions vs Ground Truth": wandb.Image(fig, caption=f"Epoch: {_ + 1}, Batch: {batch_idx}")
        })

        plt.close(fig)
      except:
        pass

# %%
def slice_spaces(array):
  # performing jump based space divisions

  jump_coords = [26, 26, 26]


  # # lists to store each space slice to be saved
  array_space_slices = []
  # segmap_space_slices = []


  # logic to slice a space out of a 3d array
  # each slice space is then saved as an nii.gz file to be read by the dataloader while training
  # space slices are created for both, the image and the segmentation mask

  it0 = 1

  while it0 * jump_coords[1] < array.shape[1]:

      it1 = 1
      while it1 * jump_coords[2] < array.shape[2]:
          it2 = 1
          while it2 * jump_coords[0] < array.shape[0]:

              # slicing space from image
              curr_image_slice = array[(it2 - 1) * jump_coords[0]:it2*jump_coords[0], (it0-1) * jump_coords[1]:it0*jump_coords[1], (it1-1)*jump_coords[2]:it1*jump_coords[2]]
              array_space_slices.append(curr_image_slice)
              it2 += 1
          it1 += 1
      it0 += 1

  return np.array(array_space_slices)

# %%
def reconstruct_original_array(slices, original_shape, jump_coords=[26, 26, 26]):
    reconstructed_array = np.zeros(original_shape)
    index = 0

    it0 = 1
    while it0 * jump_coords[1] < original_shape[1]:
      it1 = 1
      while it1 * jump_coords[2] < original_shape[2]:
          it2 = 1
          while it2 * jump_coords[0] < original_shape[0]:

              if index < len(slices):
                # slicing space from image
                reconstructed_array[(it2 - 1) * jump_coords[0]:it2*jump_coords[0], (it0-1) * jump_coords[1]:it0*jump_coords[1], (it1-1)*jump_coords[2]:it1*jump_coords[2]] = slices[index]
                index += 1
              else:
                print(f'arre re re')
                break

              it2 += 1
          it1 += 1
      it0 += 1

    return reconstructed_array
